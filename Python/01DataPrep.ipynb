# %%
# import required libraries

import json

import pandas as pd

import urllib.request as request

# %% [markdown]
# ## Get Senator Info

# %%
# Read in the data from Json API

with request.urlopen('https://www.govtrack.us/api/v2/role?current=true&role_type=senator') as response:
        source = response.read()
        data = json.loads(source)

# %%
# Create Empty lists

state_list = []

name_list = []

first_name_list = []

last_name_list = []

party_list = []

gender_list = []

startdate_list = []

enddate_list = []

phone_list = []

twitterid_list = []

youtubeid_list = []

website_list = []

link_list = []

# %%
for i in range(100):
    
    # Extract the relevant information
    
    state = data['objects'][i]['state']
    
    name = data['objects'][i]['person']['sortname']
    
    firstname = data['objects'][i]['person']['firstname']
    
    lastname = data['objects'][i]['person']['lastname']
    
    gender = data['objects'][i]['person']['gender_label']
    
    party = data['objects'][i]['party']
    
    startdate = data['objects'][i]['startdate']
    
    enddate = data['objects'][i]['enddate']
    
    phone = data['objects'][i]['phone']
    
    twitterid = data['objects'][i]['person']['twitterid']
    
    youtubeid = data['objects'][i]['person']['youtubeid']
    
    website = data['objects'][i]['website']
    
    link = data['objects'][i]['person']['link']
    
    
    # Appending to empty list
    
    state_list.append(state)
    
    party_list.append(party)
    
    name_list.append(name)
    
    first_name_list.append(firstname)
    
    last_name_list.append(lastname)
    
    gender_list.append(gender)
    
    startdate_list.append(startdate)
    
    enddate_list.append(enddate)
    
    phone_list.append(phone)
    
    twitterid_list.append(twitterid)
    
    youtubeid_list.append(youtubeid)
    
    website_list.append(website)
    
    link_list.append(link)

# %%
data_combine = {'Name':name_list, 'FirstName':first_name_list, 'LastName':last_name_list, 'State':state_list, 'Gender':gender_list, 'Party':party_list, 'StartDate':startdate_list, 'EndDate':enddate_list, 'Contact':phone_list, 'Twitter_ID':twitterid_list, 'Youtube_ID':youtubeid_list, 'Website':website_list, 'Link':link_list}

# %%
# Converting lists to DataFrame

df = pd.DataFrame(data_combine)

# %%
df.head()
# Out:
#                              Name FirstName   LastName State  Gender  \
# 0  Alexander, Lamar (Sen.) [R-TN]     Lamar  Alexander    TN    Male
# 1    Collins, Susan (Sen.) [R-ME]     Susan    Collins    ME  Female
# 2      Cornyn, John (Sen.) [R-TX]      John     Cornyn    TX    Male
# 3   Durbin, Richard (Sen.) [D-IL]   Richard     Durbin    IL    Male
# 4     Enzi, Michael (Sen.) [R-WY]   Michael       Enzi    WY    Male
#
#         Party   StartDate     EndDate       Contact      Twitter_ID  \
# 0  Republican  2015-01-06  2021-01-03  202-224-4944    SenAlexander
# 1  Republican  2015-01-06  2021-01-03  202-224-2523  SenatorCollins
# 2  Republican  2015-01-06  2021-01-03  202-224-2934      JohnCornyn
# 3    Democrat  2015-01-06  2021-01-03  202-224-2152   SenatorDurbin
# 4  Republican  2015-01-06  2021-01-03  202-224-3424     SenatorEnzi
#
#             Youtube_ID                                  Website  \
# 0       lamaralexander  https://www.alexander.senate.gov/public
# 1  SenatorSusanCollins           https://www.collins.senate.gov
# 2        senjohncornyn            https://www.cornyn.senate.gov
# 3        SenatorDurbin            https://www.durbin.senate.gov
# 4          senatorenzi              https://www.enzi.senate.gov
#
#                                                 Link
# 0  https://www.govtrack.us/congress/members/lamar...
# 1  https://www.govtrack.us/congress/members/susan...
# 2  https://www.govtrack.us/congress/members/john_...
# 3  https://www.govtrack.us/congress/members/richa...
# 4  https://www.govtrack.us/congress/members/micha...

# %%
data_combine2 = {'Name':name_list, 'OtherName':first_name_list + last_name_list, 'Gender':gender_list, 'Party':party_list, 'EndDate':enddate_list, 'Contact':phone_list, 'Twitter_ID':twitterid_list, 'Youtube_ID':youtubeid_list, 'Website':website_list, 'Link':link_list}

# %%
df['Full Name'] =  df['FirstName'] + ' ' +  df['LastName']

df['Term Date'] = df['StartDate'] + ' to ' + df['EndDate']

df.head()
# Out:
#                              Name FirstName   LastName State  Gender  \
# 0  Alexander, Lamar (Sen.) [R-TN]     Lamar  Alexander    TN    Male
# 1    Collins, Susan (Sen.) [R-ME]     Susan    Collins    ME  Female
# 2      Cornyn, John (Sen.) [R-TX]      John     Cornyn    TX    Male
# 3   Durbin, Richard (Sen.) [D-IL]   Richard     Durbin    IL    Male
# 4     Enzi, Michael (Sen.) [R-WY]   Michael       Enzi    WY    Male
#
#         Party   StartDate     EndDate       Contact      Twitter_ID  \
# 0  Republican  2015-01-06  2021-01-03  202-224-4944    SenAlexander
# 1  Republican  2015-01-06  2021-01-03  202-224-2523  SenatorCollins
# 2  Republican  2015-01-06  2021-01-03  202-224-2934      JohnCornyn
# 3    Democrat  2015-01-06  2021-01-03  202-224-2152   SenatorDurbin
# 4  Republican  2015-01-06  2021-01-03  202-224-3424     SenatorEnzi
#
#             Youtube_ID                                  Website  \
# 0       lamaralexander  https://www.alexander.senate.gov/public
# 1  SenatorSusanCollins           https://www.collins.senate.gov
# 2        senjohncornyn            https://www.cornyn.senate.gov
# 3        SenatorDurbin            https://www.durbin.senate.gov
# 4          senatorenzi              https://www.enzi.senate.gov
#
#                                                 Link        Full Name  \
# 0  https://www.govtrack.us/congress/members/lamar...  Lamar Alexander
# 1  https://www.govtrack.us/congress/members/susan...    Susan Collins
# 2  https://www.govtrack.us/congress/members/john_...      John Cornyn
# 3  https://www.govtrack.us/congress/members/richa...   Richard Durbin
# 4  https://www.govtrack.us/congress/members/micha...     Michael Enzi
#
#                   Term Date
# 0  2015-01-06 to 2021-01-03
# 1  2015-01-06 to 2021-01-03
# 2  2015-01-06 to 2021-01-03
# 3  2015-01-06 to 2021-01-03
# 4  2015-01-06 to 2021-01-03

# %%
df_senator = df[['Full Name', 'State', 'Gender', 'Party', 'Term Date', 'Website', 'Link']]
df_senator.head()
# Out:
#          Full Name State  Gender       Party                 Term Date  \
# 0  Lamar Alexander    TN    Male  Republican  2015-01-06 to 2021-01-03
# 1    Susan Collins    ME  Female  Republican  2015-01-06 to 2021-01-03
# 2      John Cornyn    TX    Male  Republican  2015-01-06 to 2021-01-03
# 3   Richard Durbin    IL    Male    Democrat  2015-01-06 to 2021-01-03
# 4     Michael Enzi    WY    Male  Republican  2015-01-06 to 2021-01-03
#
#                                    Website  \
# 0  https://www.alexander.senate.gov/public
# 1           https://www.collins.senate.gov
# 2            https://www.cornyn.senate.gov
# 3            https://www.durbin.senate.gov
# 4              https://www.enzi.senate.gov
#
#                                                 Link
# 0  https://www.govtrack.us/congress/members/lamar...
# 1  https://www.govtrack.us/congress/members/susan...
# 2  https://www.govtrack.us/congress/members/john_...
# 3  https://www.govtrack.us/congress/members/richa...
# 4  https://www.govtrack.us/congress/members/micha...

# %% [markdown]
# ## Get Approval Data

# %%
approval_df = pd.read_excel('../Data/senator_approve.xlsx')

approval_df.head()
# Out:
#      State      Politician  Approve  Disapprove  Don't Know / No Opinion  \
# 0  Alabama  Richard Shelby     0.47        0.27                     0.26
# 1  Alabama      Doug Jones     0.40        0.35                     0.25
# 2   Alaska  Lisa Murkowski     0.39        0.42                     0.19
# 3   Alaska    Dan Sullivan     0.40        0.33                     0.27
# 4  Arizona         Jon Kyl     0.35        0.24                     0.42
#
#    Margin of Error
# 0             0.01
# 1             0.01
# 2             0.05
# 3             0.05
# 4             0.01

# %%
df_senator_approval = pd.merge(df_senator, approval_df, how='left', left_on=['Full Name'], right_on=['Politician'])

# %%
df_senator_approval.head()
# Out:
#          Full Name State_x  Gender       Party                 Term Date  \
# 0  Lamar Alexander      TN    Male  Republican  2015-01-06 to 2021-01-03
# 1    Susan Collins      ME  Female  Republican  2015-01-06 to 2021-01-03
# 2      John Cornyn      TX    Male  Republican  2015-01-06 to 2021-01-03
# 3   Richard Durbin      IL    Male    Democrat  2015-01-06 to 2021-01-03
# 4     Michael Enzi      WY    Male  Republican  2015-01-06 to 2021-01-03
#
#                                    Website  \
# 0  https://www.alexander.senate.gov/public
# 1           https://www.collins.senate.gov
# 2            https://www.cornyn.senate.gov
# 3            https://www.durbin.senate.gov
# 4              https://www.enzi.senate.gov
#
#                                                 Link    State_y  \
# 0  https://www.govtrack.us/congress/members/lamar...  Tennessee
# 1  https://www.govtrack.us/congress/members/susan...      Maine
# 2  https://www.govtrack.us/congress/members/john_...      Texas
# 3  https://www.govtrack.us/congress/members/richa...        NaN
# 4  https://www.govtrack.us/congress/members/micha...        NaN
#
#         Politician  Approve  Disapprove  Don't Know / No Opinion  \
# 0  Lamar Alexander     0.43        0.30                     0.27
# 1    Susan Collins     0.53        0.38                     0.09
# 2      John Cornyn     0.43        0.25                     0.32
# 3              NaN      NaN         NaN                      NaN
# 4              NaN      NaN         NaN                      NaN
#
#    Margin of Error
# 0             0.01
# 1             0.02
# 2             0.01
# 3              NaN
# 4              NaN

# %%
df_senator_approval.[]
# Out:
# Full Name                  100
# State_x                    100
# Gender                     100
# Party                      100
# Term Date                  100
# Website                    100
# Link                       100
# State_y                     71
# Politician                  71
# Approve                     71
# Disapprove                  71
# Don't Know / No Opinion     71
# Margin of Error             71
# dtype: int64

# %%
null_data = df_senator_approval[df_senator_approval.isnull().any(axis=1)]

# %%
null_data.to_csv('../Data/null_approval.xlsx')
